# %% [markdown]
# <a href="https://colab.research.google.com/github/PHYRA47/Biometrics-II/blob/main/Biometrics%20Skills%20-%20Amine%20Nait-Ali/skill1_Face_Recognition_for_Verification/biometrics_skill_1_Face_Recognition_for_Verification_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports and Environment Setup

# %% [markdown]
# ## Import Modules and Setup

# %%
#@title Authenticate with Google Acoount and do imports { display-mode: "form" }
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from google.colab import auth, files
from oauth2client.client import GoogleCredentials

import os

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#@title Import standard machine learning and data science modules
import numpy as np
import pandas as pd
import random
import os
import shutil
from tqdm import tqdm
from glob import glob
import math
from functools import partial

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

# Import metrics
from scipy.spatial import distance
from sklearn.metrics import accuracy_score

# Import zoom function
# from keras_preprocessing.image import random_zoom


from PIL import Image
from IPython.display import display
from matplotlib.image import pil_to_array, imread
from matplotlib import pyplot as plt

np.random.seed(42)
random.seed(42)

tqdm.pandas()

os.environ["KERAS_BACKEND"] = "tensorflow"

# %%
#@title Import Keras modules
import tensorflow as tf
import keras
from keras.utils import image_dataset_from_directory, array_to_img, img_to_array, load_img, plot_model
from keras.layers import RandomZoom
from keras import layers
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense, Input, Lambda, AveragePooling2D, Activation, PReLU, ReLU, Add, GlobalAveragePooling2D
from keras.applications.resnet_v2 import ResNet50V2, preprocess_input
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, TensorBoard, TerminateOnNaN
from keras.optimizers import SGD, Adam
import keras.backend as K

AUTOTUNE = tf.data.AUTOTUNE

# %%
#@title Helper functions: image processing and useful plots { display-mode: "form" }
# Google Drive upload/download helpers
def drive_upload_file(full_filename):
  filename = os.path.basename(full_filename)
  file_to_upload = drive.CreateFile({'title': filename})
  file_to_upload.SetContentFile(full_filename)
  file_to_upload.Upload()

def drive_download_file(file_id, local_path='./'):
  # A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
  downloaded = drive.CreateFile({'id': file_id})
  downloaded.FetchMetadata()
  fn = downloaded.metadata.get('originalFilename')
  full_fn = os.path.join(local_path, fn)
  downloaded.GetContentFile(full_fn)
  return full_fn

# Dataset reading helpers
def filter_df(df, min_images_count=0):
  df = df.sort_values('images', ascending=False)
  return df[df.images >= min_images_count]

# Undo ImageNet preprocessing to show images from batch generator
vgg_mean = np.array([123.68, 116.779, 103.939], dtype=np.float32)  # RGB
de_preproc = lambda x: np.clip((x[..., ::-1]+vgg_mean)/255., 0, 1)

# Visualization helpers
# Images root dir
img_root_dir = 'input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled'

# equal probabilities
equal_apriori = 0.5

# number of thresholds
num_thresholds = 100
# generate a list of  n thresholds between 0.0 and 1.0
thresholds = [i/num_thresholds for i in range(num_thresholds)]

def plot_scores(imposter, genuine):
  """ Plot the scores of the genuine and imposters """

  plt.figure(figsize=(10, 6))

  # Draws a histogram to show score frequencies with values.
  plt.hist(imposter, alpha=0.50, label='Imposter', color='red')
  plt.hist(genuine, alpha=0.50, label='Genuine', color='green')

  # Adding labels and titles to the plot
  plt.xlabel('Score')
  plt.ylabel('Frequency')
  # plt.title('Distribution of Genuine and Imposter Scores')
  plt.grid(True)

  # draw the key/legend
  plot_legends()

  # show the plot
  show_plot()

def calculate_cost(imposter, genuine):
  """ For both users, calculates a confusion matrix and then calculates cost per threshold """

  # generate n number of thresholds

  far = []
  frr = []
  cost = []

  # for each threshold, calculate confusion matrix.
  for t in thresholds:

    FP = 0
    FN = 0
    TP = 0
    TN = 0

    # go through imposters
    for score in imposter:

      if score >= t:
        # imposter passes as a genuine user
        FP += 1
      else:
        # imposter correctly rejected
        TN += 1

    for score in genuine:
      if score >= t:
        # genuine user correctly identified
        TP += 1
      else:
        # genuine user incorrectly rejected
        FN += 1

    far_current = float(FP) / float(len(imposter))
    frr_current = float(FN) / float(len(genuine))

    # calculate our false accept rate(FAR) and add to list
    far.append(far_current)

    # calculate our false reject rate(FRR) and add to list
    frr.append(frr_current)

  return far, frr

def plot_DET_with_EER(far, frr, far_optimum, frr_optimum):
  """ Plots a DET curve with the most suitable operating point based on threshold values"""

  # Plot the DET curve based on the FAR and FRR values
  plt.plot(far, frr, linestyle="--", linewidth=4, label="DET Curve")

  # Plot the optimum point on the DET Curve
  plt.plot(far_optimum,frr_optimum, "ro", label="Suitable Operating Point")

  # Draw the default DET Curve from 1-1
  plt.plot([1.0,0.0], [0.0,1.0],"k--")

  # Draws the key/legend
  plot_legends()

  # Displays plots
  show_plot()

"""
def plot_DET_with_EER(far, frr, addedPlots=None):
    plt.figure(figsize=(10, 6))
    plt.plot(far, frr, linestyle="--", color='blue', linewidth=4, label="DET Curve")
    if addedPlots is not None:
        addedPlots()
    plt.xlabel('False Acceptance Rate (FAR)')
    plt.ylabel('False Rejection Rate (FRR)')
    plt.title('Detection Error Tradeoff (DET) curve')
    plt.legend()
    plt.grid()
    plt.show()
"""

def plot_FAR_vs_FRR(far, frr, eer_threshold):

  plt.figure(figsize=(10, 6))

  # Plot FAR and FRR
  plt.plot(thresholds, far, 'g-', label='FAR', color='red')
  plt.plot(thresholds, frr, 'b-', label='FRR', color='blue')
  plt.axvline(eer_threshold, color='green', linestyle='--', label=f'EER = {eer:.4f} at Threshold = {eer_threshold:.2f}')


  plt.xlabel('Threshold'), plt.ylabel('Error Rate')
  # plt.title('FAR and FRR vs Threshold')
  # Draws the key/legend
  plot_legends(), plt.grid()

  # Displays plots
  show_plot()
"""
def find_EER(far, frr):
  # Returns the most optimal FAR and FRR values

  # The lower the equal error rate value,
  # the higher the accuracy of the biometric system.

  # smallest value is most accurate
  far = np.array(far)
  frr = np.array(frr)
  delta = np.abs(far - frr)
  t = np.argmin(delta)
  far_optimum = far[t]
  frr_optimum = frr[t]
  threshold_optimum = thresholds[t]

  return far_optimum, frr_optimum, threshold_optimum

"""
def find_EER(far_values, frr_values, thresholds):
    # Calculate the absolute differences between FAR and FRR
    delta = np.abs(np.array(far_values) - np.array(frr_values))

    # Find the index where the difference is minimum (EER point)
    eer_index = np.argmin(delta)

    # Return the FAR at EER, FRR at EER, and the threshold at EER
    return far_values[eer_index], frr_values[eer_index], thresholds[eer_index]

def plot_legends():
  legend = plt.legend(loc='upper center', shadow=True, fontsize='x-large')
  legend.get_frame().set_facecolor('#ffffff')

def show_plot():
  plt.show()

def extract_template(image_paths, model, target_size=(224, 224), batch_size=32):
  """
  Extract image template from a filename list using a Keras model and tf.data.Dataset.

  Args:
    image_paths: A list of image filenames.
    model: Keras model with a predict method.
    target_size: Tuple (height, width) for resizing images.
    batch_size: Batch size for prediction.

  Returns:
    A list of model prediction results.
  """

  def preprocess_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (256, 256))
    img = zoom_image(img)
    # img = preprocess_input(img)
    return img

  zoom_image = keras.Sequential([
    keras.layers.RandomZoom((-0.5, -0.5)),
    keras.layers.Resizing(target_size[0], target_size[1]),
  ])
  dataset = tf.data.Dataset.from_tensor_slices(image_paths)
  dataset = dataset.map(preprocess_image)
  dataset = dataset.batch(batch_size)
  dataset = dataset.prefetch(tf.data.AUTOTUNE)

  predictions = model.predict(dataset)

  return predictions.tolist()

def name_to_image_path(root_dir, name, image_num):
  return f'{root_dir}/{name}/{name}_{image_num:04d}.jpg'

def evaluate_model(model, pairs_file='./input/lfw-dataset/course-pairsDevTest.csv'):
  # Cut our model at the 'embedding' layer level and convert it to template extractor
  embedding_out = model.get_layer('face_embedding').output
  template_extrator = Model(inputs=[input_layer], outputs=[embedding_out])

  # Read pairs matched and mismatched for dev dataset
  print('Preparing stats from dev set')
  test_pairs = pd.read_csv(pairs_file)
  test_pairs['img_fn1'] = test_pairs.apply(lambda row: name_to_image_path(img_root_dir, row['name1'], row['imagenum1']), axis=1)
  test_pairs['img_fn2'] = test_pairs.apply(lambda row: name_to_image_path(img_root_dir, row['name2'], row['imagenum2']), axis=1)

  # Apply the template model to all images
  test_pairs['template1'] = extract_template(test_pairs['img_fn1'], template_extrator, target_size)
  test_pairs['template2'] = extract_template(test_pairs['img_fn2'], template_extrator, target_size)
  test_pairs['cos_distance'] = test_pairs.apply(lambda row: distance.cosine(row['template1'], row['template2'])/2., axis=1)  # cos distance rescaled to (0,1)

  match_scores = test_pairs[test_pairs.match_pair==1]['cos_distance']
  mismatch_scores = test_pairs[test_pairs.match_pair==0]['cos_distance']

  # Plot model's stats
  genuine = match_scores.values
  imposter = mismatch_scores.values

  far, frr = calculate_cost(imposter, genuine)
  far_optimum, frr_optimum, err_threshold = find_EER(far, frr)

  # Calculate the EER value
  eer = (far_optimum + frr_optimum) / 2
  print(f"Equal Error Rate (EER): {eer:.4f}")

  plot_scores(imposter, genuine)
  plot_DET_with_EER(far, frr, far_optimum, frr_optimum)
  plot_FAR_vs_FRR(far, frr, err_threshold)
  print(f'EER at threshold: {err_threshold}')

  # Now let's calculate accuracy for test set
  test_pairs['pred_match_pair'] = test_pairs['cos_distance'] < err_threshold
  test_pairs['pred_match_pair'] = test_pairs['pred_match_pair'].astype(int)

  print(f'At threshold {err_threshold} accuracy score is {accuracy_score(test_pairs.match_pair.values, test_pairs.pred_match_pair.values):.4f}')
  return test_pairs

# %% [markdown]
# # Dataset preparation

# %% [markdown]
# ## Download and unpack LFW files

# %%
# Prepare Labelled Faces in the Wild dataset
# !mkdir -p input/lfw-dataset

# Download LFW file (drive id is '14ra9GYFzdyeubZ5qtSDaDAbFDKPCjdAD')
file_id = '14ra9GYFzdyeubZ5qtSDaDAbFDKPCjdAD'
drive_download_file(file_id, local_path='./input/')

# Unpack zip files
!7z x ./input/lfw-dataset.zip -o./input/lfw-dataset -aoa
!7z x ./input/lfw-dataset/lfw-deepfunneled.zip -o./input/lfw-dataset/lfw-deepfunneled -aoa

# Clean temp files
# !rm -r ./input/lfw-dataset/lfw-deepfunneled/__MACOSX/ ./input/lfw-dataset/__MACOSX/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 116495068 bytes (112 MiB)
#
# Extracting archive: ./input/lfw-dataset.zip
# --
# Path = ./input/lfw-dataset.zip
# Type = zip
# Physical Size = 116495068
#
# Everything is Ok
#
# Folders: 1
# Files: 26
# Size:       127156959
# Compressed: 116495068
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.00GHz (50653),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 126347553 bytes (121 MiB)
#
# Extracting archive: ./input/lfw-dataset/lfw-deepfunneled.zip
# --
# Path = ./input/lfw-dataset/lfw-deepfunneled.zip
# Type = zip
# Physical Size = 126347553
#
# Everything is Ok
#
# Folders: 11501
# Files: 32218
# Size:       120624344
# Compressed: 126347553

# %%
# !ls -lh **/**/**
# Out:
# -rw-r--r--  1 root root 207K Nov 24  2018 input/lfw-dataset/course-pairs.csv
# -rw-r--r--  1 root root  35K Nov 24  2018 input/lfw-dataset/course-pairsDevTest.csv
# -rwxr-xr-x  1 root root  99K May 17  2018 input/lfw-dataset/lfw_allnames.csv
# -rwxr-xr-x  1 root root 121M May 17  2018 input/lfw-dataset/lfw-deepfunneled.zip
# -rwxr-xr-x  1 root root 8.0K May 17  2018 input/lfw-dataset/lfw_readme.txt
# -rwxr-xr-x  1 root root 9.7K May 17  2018 input/lfw-dataset/matchpairsDevTest.csv
# -rwxr-xr-x  1 root root  22K May 17  2018 input/lfw-dataset/matchpairsDevTrain.csv
# -rwxr-xr-x  1 root root  17K May 17  2018 input/lfw-dataset/mismatchpairsDevTest.csv
# -rwxr-xr-x  1 root root  37K May 17  2018 input/lfw-dataset/mismatchpairsDevTrain.csv
# -rwxr-xr-x  1 root root 161K May 17  2018 input/lfw-dataset/pairs.csv
# -rwxr-xr-x  1 root root  99K May 17  2018 input/lfw-dataset/people.csv
# -rwxr-xr-x  1 root root  30K May 17  2018 input/lfw-dataset/peopleDevTest.csv
# -rwxr-xr-x  1 root root  69K May 17  2018 input/lfw-dataset/peopleDevTrain.csv
#
# input/lfw-dataset/lfw-deepfunneled:
# total 200K
# drwxr-xr-x 5751 root root 196K May 15  2018 lfw-deepfunneled
#
# input/lfw-train-test-split/logs:
# total 0
#
# input/lfw-train-test-split/train:
# total 212K
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Alejandro_Toledo
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Andre_Agassi
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Angelina_Jolie
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Ariel_Sharon
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Arnold_Schwarzenegger
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Atal_Bihari_Vajpayee
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Bill_Clinton
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Carlos_Menem
# drwxr-xr-x 2 root root  12K Jan  4 01:29 Colin_Powell
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 David_Beckham
# drwxr-xr-x 2 root root  20K Jan  4 01:29 George_W_Bush
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Gloria_Macapagal_Arroyo
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Guillermo_Coria
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Hamid_Karzai
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Hans_Blix
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Hugo_Chavez
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Igor_Ivanov
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Jack_Straw
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Jean_Chretien
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Jennifer_Aniston
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Jennifer_Lopez
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 John_Ashcroft
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Jose_Maria_Aznar
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Juan_Carlos_Ferrero
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Junichiro_Koizumi
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Laura_Bush
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Lindsay_Davenport
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Lleyton_Hewitt
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Luiz_Inacio_Lula_da_Silva
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Megawati_Sukarnoputri
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Michael_Bloomberg
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Naomi_Watts
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Nestor_Kirchner
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Paul_Bremer
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Pete_Sampras
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Recep_Tayyip_Erdogan
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Ricardo_Lagos
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Roh_Moo-hyun
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Rudolph_Giuliani
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Saddam_Hussein
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Serena_Williams
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Tiger_Woods
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Tom_Daschle
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Tom_Ridge
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Tony_Blair
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Vladimir_Putin
#
# input/lfw-train-test-split/validation:
# total 184K
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Alejandro_Toledo
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Andre_Agassi
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Angelina_Jolie
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Ariel_Sharon
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Arnold_Schwarzenegger
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Atal_Bihari_Vajpayee
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Bill_Clinton
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Carlos_Menem
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Colin_Powell
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 David_Beckham
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 George_W_Bush
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Gloria_Macapagal_Arroyo
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Guillermo_Coria
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Hamid_Karzai
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Hans_Blix
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Hugo_Chavez
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Igor_Ivanov
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Jack_Straw
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Jean_Chretien
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Jennifer_Aniston
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Jennifer_Lopez
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 John_Ashcroft
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Jose_Maria_Aznar
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Juan_Carlos_Ferrero
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Junichiro_Koizumi
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Laura_Bush
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Lindsay_Davenport
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Lleyton_Hewitt
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Luiz_Inacio_Lula_da_Silva
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Megawati_Sukarnoputri
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Michael_Bloomberg
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Naomi_Watts
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Nestor_Kirchner
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Paul_Bremer
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Pete_Sampras
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Recep_Tayyip_Erdogan
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Ricardo_Lagos
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Roh_Moo-hyun
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Rudolph_Giuliani
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Saddam_Hussein
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Serena_Williams
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Tiger_Woods
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Tom_Daschle
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Tom_Ridge
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Tony_Blair
# drwxr-xr-x 2 root root 4.0K Jan  4 01:29 Vladimir_Putin

# %% [markdown]
# ## Copy images into train-validation directories

# %%
# Load LFW labels and keep only people with > min_images_count images
df_train = filter_df(pd.read_csv('./input/lfw-dataset/peopleDevTrain.csv'), min_images_count=20)
df_train.head(), len(df_train)
# Out:
# (               name  images
#  1328  George_W_Bush     530
#  743    Colin_Powell     236
#  3842     Tony_Blair     144
#  270    Ariel_Sharon      77
#  1543    Hugo_Chavez      71,
#  46)

# %%
# Prepare a list of all images for names in train list
all_train = []
for name in df_train.name.values:
    imgs_for_name = glob(f'./input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled/{name}/*.jpg')
    all_train += [{'name': name, 'filename': fn} for fn in imgs_for_name]

# Train-validation split
df_train = pd.DataFrame(all_train)
df_train, df_val = train_test_split(df_train, train_size=0.8, stratify=df_train.name.values)

# %%
# Check split lenght
len(df_train), len(df_val)
# Out:
# (1896, 474)

# %%
# Create directories structure
root_path = 'input/lfw-train-test-split'

weights_path = './weights'
logs_path = f'{root_path}/logs'
os.makedirs(weights_path, exist_ok=True)
os.makedirs(logs_path, exist_ok=True)

train_path = f'{root_path}/train/'
validation_path = f'{root_path}/validation/'

# %%
# Make 'name' directories in the train-valid dirs
shutil.rmtree(train_path, ignore_errors=True)
shutil.rmtree(validation_path, ignore_errors=True)
os.makedirs(train_path, exist_ok=True)
os.makedirs(validation_path, exist_ok=True)

for name in df_train.name.values:
    os.makedirs(os.path.join(train_path, name), exist_ok=True)
    os.makedirs(os.path.join(validation_path, name), exist_ok=True)

print(f"Created directories: \n{train_path}, \n{validation_path}")
# Out:
# Created directories:
# input/lfw-train-test-split/train/,
# input/lfw-train-test-split/validation/

# %%
# Copy to train dir
for i, row in tqdm(df_train.iterrows()):
    shutil.copy(row['filename'], os.path.join(train_path, row['name']))

# Copy to validation dir
for i, row in tqdm(df_val.iterrows()):
    shutil.copy(row['filename'], os.path.join(validation_path, row['name']))
# Out:
# 1896it [00:00, 3735.27it/s]
# 474it [00:00, 4156.77it/s]

# %%
# Show some images
imgs_fn = glob(f'{train_path}/**/*.jpg', recursive=True)
for fn in np.random.choice(imgs_fn, size=3):
    img = Image.open(fn)
    print(fn, img.height, img.width)
    display(img)
# Out:
# input/lfw-train-test-split/train/Ariel_Sharon/Ariel_Sharon_0011.jpg 250 250
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>
# input/lfw-train-test-split/train/George_W_Bush/George_W_Bush_0073.jpg 250 250
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>
# input/lfw-train-test-split/train/Rudolph_Giuliani/Rudolph_Giuliani_0015.jpg 250 250
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>

# %% [markdown]
# # Train models

# %% [markdown]
# ## Image data generators

# %%
# !ls {train_path}/*/*.jpg
# Out:
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0001.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0004.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0005.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0006.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0007.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0008.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0009.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0010.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0011.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0012.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0013.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0014.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0015.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0016.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0017.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0018.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0019.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0020.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0021.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0024.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0025.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0026.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0028.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0030.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0031.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0032.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0033.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0036.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0037.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0038.jpg
# input/lfw-train-test-split/train//Alejandro_Toledo/Alejandro_Toledo_0039.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0002.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0003.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0004.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0005.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0006.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0008.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0009.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0010.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0012.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0013.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0015.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0016.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0018.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0019.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0020.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0021.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0022.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0023.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0025.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0026.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0027.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0029.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0030.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0031.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0032.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0033.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0034.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0035.jpg
# input/lfw-train-test-split/train//Andre_Agassi/Andre_Agassi_0036.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0002.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0003.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0004.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0005.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0008.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0009.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0010.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0011.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0012.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0013.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0014.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0015.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0017.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0018.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0019.jpg
# input/lfw-train-test-split/train//Angelina_Jolie/Angelina_Jolie_0020.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0001.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0003.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0004.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0006.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0007.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0010.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0011.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0012.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0014.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0015.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0016.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0017.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0018.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0019.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0020.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0021.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0022.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0023.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0025.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0028.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0029.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0030.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0031.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0032.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0033.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0034.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0036.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0040.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0041.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0042.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0043.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0044.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0045.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0046.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0047.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0049.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0050.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0051.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0052.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0053.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0054.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0055.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0056.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0057.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0058.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0059.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0060.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0061.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0062.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0063.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0064.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0066.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0067.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0069.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0070.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0072.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0073.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0074.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0075.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0076.jpg
# input/lfw-train-test-split/train//Ariel_Sharon/Ariel_Sharon_0077.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0001.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0003.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0004.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0005.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0006.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0007.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0009.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0010.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0011.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0014.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0015.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0016.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0017.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0018.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0020.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0022.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0023.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0024.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0025.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0026.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0027.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0028.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0029.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0030.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0031.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0032.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0035.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0036.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0037.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0038.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0039.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0040.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0041.jpg
# input/lfw-train-test-split/train//Arnold_Schwarzenegger/Arnold_Schwarzenegger_0042.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0001.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0002.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0003.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0004.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0005.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0007.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0008.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0009.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0010.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0011.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0013.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0015.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0016.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0017.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0018.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0019.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0020.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0023.jpg
# input/lfw-train-test-split/train//Atal_Bihari_Vajpayee/Atal_Bihari_Vajpayee_0024.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0001.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0003.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0004.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0005.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0006.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0007.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0008.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0009.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0011.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0012.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0013.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0014.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0015.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0019.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0020.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0021.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0022.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0023.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0024.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0025.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0026.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0028.jpg
# input/lfw-train-test-split/train//Bill_Clinton/Bill_Clinton_0029.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0001.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0002.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0004.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0005.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0006.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0007.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0010.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0011.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0012.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0013.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0014.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0015.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0016.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0018.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0019.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0020.jpg
# input/lfw-train-test-split/train//Carlos_Menem/Carlos_Menem_0021.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0001.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0002.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0003.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0004.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0005.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0007.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0009.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0010.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0013.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0014.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0015.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0016.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0017.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0019.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0020.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0021.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0022.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0023.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0024.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0025.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0027.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0028.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0029.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0031.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0032.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0034.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0035.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0036.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0037.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0038.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0039.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0040.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0041.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0044.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0045.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0047.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0048.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0050.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0051.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0052.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0053.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0054.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0055.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0056.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0057.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0058.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0060.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0062.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0063.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0065.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0066.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0067.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0068.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0069.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0070.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0071.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0072.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0073.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0074.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0076.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0077.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0078.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0079.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0080.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0081.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0082.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0084.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0086.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0087.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0088.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0089.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0090.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0091.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0092.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0093.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0094.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0095.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0096.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0097.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0098.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0099.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0100.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0103.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0104.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0105.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0108.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0109.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0110.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0112.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0113.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0115.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0116.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0118.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0121.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0123.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0125.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0126.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0127.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0128.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0130.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0132.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0133.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0134.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0135.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0136.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0138.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0139.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0140.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0141.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0142.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0143.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0144.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0145.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0146.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0147.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0148.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0149.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0150.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0151.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0152.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0154.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0155.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0156.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0157.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0158.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0159.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0160.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0161.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0162.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0163.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0164.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0165.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0166.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0167.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0169.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0173.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0174.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0175.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0176.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0177.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0179.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0180.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0181.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0183.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0185.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0186.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0187.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0188.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0189.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0190.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0191.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0192.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0193.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0194.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0195.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0196.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0197.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0198.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0199.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0200.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0201.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0202.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0203.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0205.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0207.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0208.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0209.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0210.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0211.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0212.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0213.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0214.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0216.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0217.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0218.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0219.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0220.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0221.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0223.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0224.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0225.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0226.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0228.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0229.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0230.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0231.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0232.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0233.jpg
# input/lfw-train-test-split/train//Colin_Powell/Colin_Powell_0235.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0001.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0004.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0005.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0006.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0008.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0009.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0010.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0011.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0012.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0013.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0014.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0015.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0016.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0017.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0018.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0019.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0020.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0021.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0022.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0023.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0024.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0025.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0028.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0029.jpg
# input/lfw-train-test-split/train//David_Beckham/David_Beckham_0031.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0001.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0002.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0003.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0004.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0006.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0008.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0012.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0013.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0014.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0015.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0016.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0019.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0020.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0021.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0025.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0026.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0027.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0028.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0029.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0030.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0031.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0032.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0034.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0035.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0037.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0039.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0040.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0041.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0042.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0043.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0044.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0045.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0046.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0050.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0051.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0053.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0054.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0055.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0056.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0057.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0058.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0059.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0061.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0063.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0064.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0065.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0066.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0067.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0068.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0069.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0070.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0071.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0072.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0073.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0074.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0075.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0077.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0078.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0079.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0080.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0081.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0082.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0083.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0084.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0085.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0087.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0088.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0089.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0090.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0091.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0092.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0093.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0094.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0095.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0096.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0097.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0098.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0099.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0101.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0103.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0104.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0105.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0106.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0107.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0108.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0110.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0111.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0112.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0113.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0114.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0117.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0118.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0120.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0121.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0122.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0124.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0125.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0126.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0129.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0130.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0131.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0132.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0133.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0134.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0135.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0136.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0137.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0139.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0140.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0141.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0142.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0143.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0144.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0145.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0146.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0147.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0148.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0149.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0150.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0151.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0152.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0153.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0155.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0156.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0157.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0158.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0159.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0160.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0162.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0163.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0164.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0165.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0166.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0167.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0169.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0170.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0171.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0172.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0173.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0174.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0175.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0176.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0177.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0178.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0179.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0181.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0182.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0183.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0185.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0186.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0187.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0188.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0189.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0190.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0191.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0192.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0194.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0195.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0196.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0198.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0199.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0200.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0201.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0202.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0203.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0204.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0205.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0206.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0207.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0208.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0210.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0211.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0212.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0213.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0214.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0215.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0216.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0217.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0218.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0219.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0220.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0221.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0222.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0223.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0224.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0225.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0226.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0227.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0228.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0229.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0230.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0231.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0232.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0233.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0234.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0235.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0238.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0239.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0241.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0242.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0243.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0244.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0245.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0247.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0248.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0249.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0250.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0251.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0252.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0253.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0255.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0256.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0257.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0258.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0259.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0260.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0261.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0262.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0263.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0264.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0265.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0266.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0268.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0269.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0271.jpg
# input/lfw-train-test-split/train//George_W_Bush/George_W_Bush_0272.jpg
# ...
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0031.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0032.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0033.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0035.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0036.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0037.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0038.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0039.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0040.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0041.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0042.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0043.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0044.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0045.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0046.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0048.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0049.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0050.jpg
# input/lfw-train-test-split/train//Serena_Williams/Serena_Williams_0051.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0003.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0004.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0005.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0007.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0009.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0010.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0011.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0012.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0013.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0014.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0015.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0016.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0018.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0019.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0020.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0021.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0022.jpg
# input/lfw-train-test-split/train//Tiger_Woods/Tiger_Woods_0023.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0001.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0002.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0003.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0004.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0005.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0007.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0009.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0010.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0011.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0013.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0014.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0015.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0016.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0017.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0018.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0019.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0022.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0023.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0024.jpg
# input/lfw-train-test-split/train//Tom_Daschle/Tom_Daschle_0025.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0001.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0002.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0003.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0004.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0005.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0006.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0008.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0009.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0010.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0011.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0012.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0014.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0015.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0016.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0017.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0019.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0020.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0023.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0024.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0026.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0028.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0029.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0030.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0031.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0032.jpg
# input/lfw-train-test-split/train//Tom_Ridge/Tom_Ridge_0033.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0001.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0002.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0003.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0005.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0006.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0007.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0010.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0011.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0012.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0013.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0015.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0016.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0017.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0019.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0020.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0021.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0022.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0025.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0026.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0027.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0028.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0029.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0030.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0031.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0032.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0033.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0035.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0036.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0037.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0038.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0039.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0040.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0041.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0042.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0043.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0044.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0045.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0046.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0047.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0048.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0049.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0050.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0051.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0052.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0053.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0054.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0055.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0056.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0059.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0061.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0062.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0064.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0065.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0067.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0068.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0069.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0071.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0073.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0076.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0077.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0078.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0079.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0080.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0081.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0082.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0083.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0084.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0085.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0086.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0087.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0088.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0089.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0090.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0091.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0092.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0093.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0094.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0095.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0096.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0097.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0098.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0099.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0100.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0103.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0105.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0107.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0109.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0110.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0112.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0113.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0114.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0115.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0116.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0117.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0119.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0120.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0121.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0122.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0123.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0124.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0125.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0126.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0127.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0128.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0131.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0133.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0134.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0136.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0137.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0138.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0140.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0141.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0142.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0143.jpg
# input/lfw-train-test-split/train//Tony_Blair/Tony_Blair_0144.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0001.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0002.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0003.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0004.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0005.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0006.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0007.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0008.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0013.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0016.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0018.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0020.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0021.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0022.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0023.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0024.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0025.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0027.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0028.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0029.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0030.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0031.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0032.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0033.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0034.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0035.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0036.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0037.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0039.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0040.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0041.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0042.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0043.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0044.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0045.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0046.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0047.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0048.jpg
# input/lfw-train-test-split/train//Vladimir_Putin/Vladimir_Putin_0049.jpg

# %%
# Data generators
batch_size = 32*3
target_size = (128, 128)
n_count = 3

# %%
train_img_aug = keras.Sequential([
    keras.layers.RandomZoom((-0.45, -0.55)),
    keras.layers.RandomFlip(mode="horizontal"),
    keras.layers.RandomBrightness(0.2),
    keras.layers.RandomContrast(0.2),
    keras.layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
    keras.layers.Resizing(target_size[0], target_size[1]),
    # keras.layers.Rescaling(scale=1./255)
])

valid_img_aug = keras.Sequential([
    keras.layers.RandomZoom((-0.5, -0.5)),
    keras.layers.Resizing(target_size[0], target_size[1]),
    # keras.layers.Rescaling(scale=1./255)
])

# %%
def preprocess(image, label, img_aug):
    image = img_aug(image)
    return image, label

# %%
# Train data generator
train_dataset =  keras.utils.image_dataset_from_directory(
      train_path,
      labels='inferred',
      label_mode='categorical',
      batch_size=batch_size,
      image_size=(256, 256)
  )

n_classes = len(train_dataset.class_names)
augment_train = partial(preprocess, img_aug=train_img_aug)

# # More real-life version
# train_gen = (train_dataset
#             .cache()
#             .shuffle(100)
#             .map(augment_train, num_parallel_calls=AUTOTUNE)
#             .prefetch(AUTOTUNE)
#             .repeat(n_count)
#             )

# Study-purpose version
train_gen = (train_dataset
            .map(augment_train, num_parallel_calls=AUTOTUNE)
            .repeat(n_count)
            .cache()
            .shuffle(100)
            .prefetch(AUTOTUNE)
            )

# Validation data generator
valid_dataset =  keras.utils.image_dataset_from_directory(
      validation_path,
      labels='inferred',
      label_mode='categorical',
      batch_size=1,
      image_size=(256, 256)
  )
augment_valid = partial(preprocess, img_aug=valid_img_aug)

valid_gen = (valid_dataset
            .map(augment_valid, num_parallel_calls=AUTOTUNE)
            .prefetch(AUTOTUNE)
            .cache()
            )
# Out:
# Found 1896 files belonging to 46 classes.
# Found 474 files belonging to 46 classes.

# %%
# Check that train data generator is working
batch_x, batch_y = next(iter(train_gen.take(1)))
# for x in batch_x.numpy()[:3]:
    # plt.imshow(x/255.); plt.figure()

# %%
# Validation generator
batch_x, batch_y = next(iter(valid_gen))
for x in batch_x:
  plt.imshow(x/255.); plt.figure()

# %% [markdown]
# ## Common training parameters

# %%
embedding_size = 128  # Try to change this: 64, 128, 512 ?
dropout_rate = 0.5  # Try to change this: 0.5, 0.9 ?
nb_epochs = 10  # Try to change this: 10, 50, 100 ?

# %% [markdown]
# ## RESNET50

# %%
# Set up learning rate and automatic LR decreasing
LR = 3e-4
lrate = ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.5, verbose=1)
optimizer = Adam(learning_rate=LR)
cce_loss = keras.losses.CategoricalCrossentropy(from_logits=False)

# Save best model weights
save_model = ModelCheckpoint(
    f'{weights_path}/custom-resnet50.weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

from keras.applications.resnet import ResNet50
from keras.applications.resnet import preprocess_input

# Define the input layer
input_shape = target_size + (3,)
input_layer = Input(shape=input_shape)
input_layer = layers.Lambda(preprocess_input)(input_layer)

# Load the ResNet50 model without the top layers
base_model = ResNet50(
    include_top=False,
    weights="imagenet",  # Use pretrained weights on ImageNet
    input_tensor=input_layer,
    pooling="max",  # Global max pooling for feature aggregation
    classes=n_classes,
)

# Get the output of the base model
x = base_model.output

# Flatten the output of the base model
x = layers.Flatten()(x)

# Add dense layers for face embedding
x = Dense(embedding_size)(x)
x = ReLU()(x)
x = BatchNormalization(name='face_embedding')(x)
x = Dropout(dropout_rate)(x)

# Output layer for classification
output_layer = Dense(n_classes, activation='softmax')(x)

# Create the final model
model = Model(inputs=[input_layer], outputs=[output_layer], name='resnet50')

# Compile the model
model.compile(optimizer=optimizer, loss=cce_loss, metrics=['accuracy'])
model.summary()

# Train the model
hist = model.fit(
    train_gen.repeat(10),  # Repeat dataset for additional epochs
    epochs=nb_epochs,
    validation_data=valid_gen,
    callbacks=[lrate, save_model]
)

# Save the trained model
model.save('./model/resnet50.keras')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ keras_tensor_13CLONE      │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_pad (ZeroPadding2D) │ (None, 134, 134, 3)    │              0 │ keras_tensor_13CLONE[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_conv (Conv2D)       │ (None, 64, 64, 64)     │          9,472 │ conv1_pad[1][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_bn                  │ (None, 64, 64, 64)     │            256 │ conv1_conv[1][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1_relu (Activation)   │ (None, 64, 64, 64)     │              0 │ conv1_bn[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1_pad (ZeroPadding2D) │ (None, 66, 66, 64)     │              0 │ conv1_relu[1][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ pool1_pool (MaxPooling2D) │ (None, 32, 32, 64)     │              0 │ pool1_pad[1][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_conv       │ (None, 32, 32, 64)     │          4,160 │ pool1_pool[1][0]       │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block1_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_1_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block1_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_conv       │ (None, 32, 32, 64)     │         36,928 │ conv2_block1_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block1_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_2_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block1_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_conv       │ (None, 32, 32, 256)    │         16,640 │ pool1_pool[1][0]       │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_3_conv       │ (None, 32, 32, 256)    │         16,640 │ conv2_block1_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_0_bn         │ (None, 32, 32, 256)    │          1,024 │ conv2_block1_0_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_3_bn         │ (None, 32, 32, 256)    │          1,024 │ conv2_block1_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_add (Add)    │ (None, 32, 32, 256)    │              0 │ conv2_block1_0_bn[1][… │
# │                           │                        │                │ conv2_block1_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block1_out          │ (None, 32, 32, 256)    │              0 │ conv2_block1_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_conv       │ (None, 32, 32, 64)     │         16,448 │ conv2_block1_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block2_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_1_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block2_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_conv       │ (None, 32, 32, 64)     │         36,928 │ conv2_block2_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block2_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_2_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block2_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_3_conv       │ (None, 32, 32, 256)    │         16,640 │ conv2_block2_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_3_bn         │ (None, 32, 32, 256)    │          1,024 │ conv2_block2_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_add (Add)    │ (None, 32, 32, 256)    │              0 │ conv2_block1_out[1][0… │
# │                           │                        │                │ conv2_block2_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block2_out          │ (None, 32, 32, 256)    │              0 │ conv2_block2_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_conv       │ (None, 32, 32, 64)     │         16,448 │ conv2_block2_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block3_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_1_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block3_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_conv       │ (None, 32, 32, 64)     │         36,928 │ conv2_block3_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_bn         │ (None, 32, 32, 64)     │            256 │ conv2_block3_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_2_relu       │ (None, 32, 32, 64)     │              0 │ conv2_block3_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_3_conv       │ (None, 32, 32, 256)    │         16,640 │ conv2_block3_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_3_bn         │ (None, 32, 32, 256)    │          1,024 │ conv2_block3_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_add (Add)    │ (None, 32, 32, 256)    │              0 │ conv2_block2_out[1][0… │
# │                           │                        │                │ conv2_block3_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2_block3_out          │ (None, 32, 32, 256)    │              0 │ conv2_block3_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_conv       │ (None, 16, 16, 128)    │         32,896 │ conv2_block3_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block1_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_1_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block1_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_conv       │ (None, 16, 16, 128)    │        147,584 │ conv3_block1_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block1_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_2_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block1_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_conv       │ (None, 16, 16, 512)    │        131,584 │ conv2_block3_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_3_conv       │ (None, 16, 16, 512)    │         66,048 │ conv3_block1_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_0_bn         │ (None, 16, 16, 512)    │          2,048 │ conv3_block1_0_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_3_bn         │ (None, 16, 16, 512)    │          2,048 │ conv3_block1_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_add (Add)    │ (None, 16, 16, 512)    │              0 │ conv3_block1_0_bn[1][… │
# │                           │                        │                │ conv3_block1_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block1_out          │ (None, 16, 16, 512)    │              0 │ conv3_block1_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_conv       │ (None, 16, 16, 128)    │         65,664 │ conv3_block1_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block2_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_1_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block2_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_conv       │ (None, 16, 16, 128)    │        147,584 │ conv3_block2_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block2_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_2_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block2_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_3_conv       │ (None, 16, 16, 512)    │         66,048 │ conv3_block2_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_3_bn         │ (None, 16, 16, 512)    │          2,048 │ conv3_block2_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_add (Add)    │ (None, 16, 16, 512)    │              0 │ conv3_block1_out[1][0… │
# │                           │                        │                │ conv3_block2_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block2_out          │ (None, 16, 16, 512)    │              0 │ conv3_block2_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_conv       │ (None, 16, 16, 128)    │         65,664 │ conv3_block2_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block3_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_1_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block3_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_conv       │ (None, 16, 16, 128)    │        147,584 │ conv3_block3_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block3_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_2_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block3_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_3_conv       │ (None, 16, 16, 512)    │         66,048 │ conv3_block3_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_3_bn         │ (None, 16, 16, 512)    │          2,048 │ conv3_block3_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_add (Add)    │ (None, 16, 16, 512)    │              0 │ conv3_block2_out[1][0… │
# │                           │                        │                │ conv3_block3_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block3_out          │ (None, 16, 16, 512)    │              0 │ conv3_block3_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_conv       │ (None, 16, 16, 128)    │         65,664 │ conv3_block3_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block4_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_1_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block4_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_conv       │ (None, 16, 16, 128)    │        147,584 │ conv3_block4_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_bn         │ (None, 16, 16, 128)    │            512 │ conv3_block4_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_2_relu       │ (None, 16, 16, 128)    │              0 │ conv3_block4_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_3_conv       │ (None, 16, 16, 512)    │         66,048 │ conv3_block4_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_3_bn         │ (None, 16, 16, 512)    │          2,048 │ conv3_block4_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_add (Add)    │ (None, 16, 16, 512)    │              0 │ conv3_block3_out[1][0… │
# │                           │                        │                │ conv3_block4_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv3_block4_out          │ (None, 16, 16, 512)    │              0 │ conv3_block4_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_conv       │ (None, 8, 8, 256)      │        131,328 │ conv3_block4_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block1_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block1_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block1_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block1_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block1_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_0_conv       │ (None, 8, 8, 1024)     │        525,312 │ conv3_block4_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block1_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_0_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block1_0_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block1_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block1_0_bn[1][… │
# │                           │                        │                │ conv4_block1_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block1_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block1_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_conv       │ (None, 8, 8, 256)      │        262,400 │ conv4_block1_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block2_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block2_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block2_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block2_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block2_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block2_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block2_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block1_out[1][0… │
# │                           │                        │                │ conv4_block2_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block2_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block2_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_conv       │ (None, 8, 8, 256)      │        262,400 │ conv4_block2_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block3_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block3_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block3_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block3_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block3_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block3_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block3_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block2_out[1][0… │
# │                           │                        │                │ conv4_block3_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block3_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block3_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_conv       │ (None, 8, 8, 256)      │        262,400 │ conv4_block3_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block4_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block4_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block4_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block4_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block4_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block4_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block4_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block3_out[1][0… │
# │                           │                        │                │ conv4_block4_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block4_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block4_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_conv       │ (None, 8, 8, 256)      │        262,400 │ conv4_block4_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block5_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block5_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block5_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block5_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block5_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block5_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block5_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block4_out[1][0… │
# │                           │                        │                │ conv4_block5_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block5_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block5_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_conv       │ (None, 8, 8, 256)      │        262,400 │ conv4_block5_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block6_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_1_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block6_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_conv       │ (None, 8, 8, 256)      │        590,080 │ conv4_block6_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_bn         │ (None, 8, 8, 256)      │          1,024 │ conv4_block6_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_2_relu       │ (None, 8, 8, 256)      │              0 │ conv4_block6_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_3_conv       │ (None, 8, 8, 1024)     │        263,168 │ conv4_block6_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_3_bn         │ (None, 8, 8, 1024)     │          4,096 │ conv4_block6_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_add (Add)    │ (None, 8, 8, 1024)     │              0 │ conv4_block5_out[1][0… │
# │                           │                        │                │ conv4_block6_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv4_block6_out          │ (None, 8, 8, 1024)     │              0 │ conv4_block6_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_1_conv       │ (None, 4, 4, 512)      │        524,800 │ conv4_block6_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_1_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block1_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_1_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block1_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_conv       │ (None, 4, 4, 512)      │      2,359,808 │ conv5_block1_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block1_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block1_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_0_conv       │ (None, 4, 4, 2048)     │      2,099,200 │ conv4_block6_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_3_conv       │ (None, 4, 4, 2048)     │      1,050,624 │ conv5_block1_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_0_bn         │ (None, 4, 4, 2048)     │          8,192 │ conv5_block1_0_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_3_bn         │ (None, 4, 4, 2048)     │          8,192 │ conv5_block1_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_add (Add)    │ (None, 4, 4, 2048)     │              0 │ conv5_block1_0_bn[1][… │
# │                           │                        │                │ conv5_block1_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_out          │ (None, 4, 4, 2048)     │              0 │ conv5_block1_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_conv       │ (None, 4, 4, 512)      │      1,049,088 │ conv5_block1_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block2_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block2_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_conv       │ (None, 4, 4, 512)      │      2,359,808 │ conv5_block2_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block2_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block2_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_3_conv       │ (None, 4, 4, 2048)     │      1,050,624 │ conv5_block2_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_3_bn         │ (None, 4, 4, 2048)     │          8,192 │ conv5_block2_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_add (Add)    │ (None, 4, 4, 2048)     │              0 │ conv5_block1_out[1][0… │
# │                           │                        │                │ conv5_block2_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_out          │ (None, 4, 4, 2048)     │              0 │ conv5_block2_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_conv       │ (None, 4, 4, 512)      │      1,049,088 │ conv5_block2_out[1][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block3_1_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block3_1_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_conv       │ (None, 4, 4, 512)      │      2,359,808 │ conv5_block3_1_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_bn         │ (None, 4, 4, 512)      │          2,048 │ conv5_block3_2_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_relu       │ (None, 4, 4, 512)      │              0 │ conv5_block3_2_bn[1][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_3_conv       │ (None, 4, 4, 2048)     │      1,050,624 │ conv5_block3_2_relu[1… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_3_bn         │ (None, 4, 4, 2048)     │          8,192 │ conv5_block3_3_conv[1… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_add (Add)    │ (None, 4, 4, 2048)     │              0 │ conv5_block2_out[1][0… │
# │                           │                        │                │ conv5_block3_3_bn[1][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_out          │ (None, 4, 4, 2048)     │              0 │ conv5_block3_add[1][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pool                  │ (None, 2048)           │              0 │ conv5_block3_out[1][0] │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 2048)           │              0 │ max_pool[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 128)            │        262,272 │ flatten[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 128)            │              0 │ dense[1][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ face_embedding            │ (None, 128)            │            512 │ re_lu[1][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 128)            │              0 │ face_embedding[1][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 46)             │          5,934 │ dropout[1][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 23,856,430 (91.01 MB)
#  Trainable params: 23,803,054 (90.80 MB)
#  Non-trainable params: 53,376 (208.50 KB)
# Epoch 1/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.7770 - loss: 0.9999
# Epoch 1: val_loss improved from inf to 0.27546, saving model to ./weights/custom-resnet50.weights.h5
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 282s 361ms/step - accuracy: 0.7773 - loss: 0.9988 - val_accuracy: 0.9409 - val_loss: 0.2755 - learning_rate: 3.0000e-04
# Epoch 2/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 1.0000 - loss: 0.0040
# Epoch 2: val_loss improved from 0.27546 to 0.25634, saving model to ./weights/custom-resnet50.weights.h5
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 193s 304ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9451 - val_loss: 0.2563 - learning_rate: 3.0000e-04
# Epoch 3/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 3: val_loss improved from 0.25634 to 0.24993, saving model to ./weights/custom-resnet50.weights.h5
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 182s 304ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9494 - val_loss: 0.2499 - learning_rate: 3.0000e-04
# Epoch 4/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 4: val_loss did not improve from 0.24993
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 176s 293ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9494 - val_loss: 0.2602 - learning_rate: 3.0000e-04
# Epoch 5/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 1.0000 - loss: 7.5851e-04
# Epoch 5: val_loss did not improve from 0.24993
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 175s 292ms/step - accuracy: 1.0000 - loss: 7.5838e-04 - val_accuracy: 0.9494 - val_loss: 0.2539 - learning_rate: 3.0000e-04
# Epoch 6/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 1.0000 - loss: 5.2857e-04
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 6: val_loss did not improve from 0.24993
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 177s 295ms/step - accuracy: 1.0000 - loss: 5.2852e-04 - val_accuracy: 0.9451 - val_loss: 0.2537 - learning_rate: 3.0000e-04
# Epoch 7/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 1.0000 - loss: 3.7420e-04
# Epoch 7: val_loss did not improve from 0.24993
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 201s 294ms/step - accuracy: 1.0000 - loss: 3.7417e-04 - val_accuracy: 0.9494 - val_loss: 0.2521 - learning_rate: 1.5000e-04
# Epoch 8/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 1.0000 - loss: 3.0933e-04
# Epoch 8: val_loss improved from 0.24993 to 0.24693, saving model to ./weights/custom-resnet50.weights.h5
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 209s 306ms/step - accuracy: 1.0000 - loss: 3.0931e-04 - val_accuracy: 0.9515 - val_loss: 0.2469 - learning_rate: 1.5000e-04
# Epoch 9/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 1.0000 - loss: 2.7335e-04
# Epoch 9: val_loss did not improve from 0.24693
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 194s 293ms/step - accuracy: 1.0000 - loss: 2.7334e-04 - val_accuracy: 0.9473 - val_loss: 0.2547 - learning_rate: 1.5000e-04
# Epoch 10/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 1.0000 - loss: 2.1836e-04
# Epoch 10: val_loss did not improve from 0.24693
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 201s 293ms/step - accuracy: 1.0000 - loss: 2.1834e-04 - val_accuracy: 0.9409 - val_loss: 0.2552 - learning_rate: 1.5000e-04
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-805333407d7c> in <cell line: 64>()
#      62
#      63 # Save the trained model
# ---> 64 model.save('./model/resnet50.keras')
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py in save_model(model, filepath, weights_format, zipped)
#     139                 f.write(zip_filepath.getvalue())
#     140         else:
# --> 141             with open(filepath, "wb") as f:
#     142                 _save_model_to_fileobj(model, f, weights_format)
#     143
#
# FileNotFoundError: [Errno 2] No such file or directory: './model/resnet50.keras'

# %%
model.save('/content/models/resnet50.keras')

# %%
from keras.models import load_model

model = load_model('/content/models/resnet50.keras')

# %%
embedding_out = model.get_layer('face_embedding').output

template_extractor = Model(inputs=model.input, outputs=embedding_out)

# %%
plt.figure(figsize=(5, 4))
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
#plt.title(f'Training and Validation Loss for {model.name}') # Add model name as title
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
def evaluate_model(model, pairs_file='./input/lfw-dataset/course-pairsDevTest.csv'):
  # Cut our model at the 'embedding' layer level and convert it to template extractor
  embedding_out = model.get_layer('face_embedding').output
  # Fix: Use model.input instead of [input_layer]
  template_extrator = Model(inputs=model.input, outputs=[embedding_out])

  # ... (rest of the function remains the same) ...
  # Read pairs matched and mismatched for dev dataset
  print('Preparing stats from dev set')
  test_pairs = pd.read_csv(pairs_file)
  test_pairs['img_fn1'] = test_pairs.apply(lambda row: name_to_image_path(img_root_dir, row['name1'], row['imagenum1']), axis=1)
  test_pairs['img_fn2'] = test_pairs.apply(lambda row: name_to_image_path(img_root_dir, row['name2'], row['imagenum2']), axis=1)

  # Apply the template model to all images
  test_pairs['template1'] = extract_template(test_pairs['img_fn1'], template_extrator, target_size)
  test_pairs['template2'] = extract_template(test_pairs['img_fn2'], template_extrator, target_size)
  test_pairs['cos_distance'] = test_pairs.apply(lambda row: distance.cosine(row['template1'], row['template2'])/2., axis=1)  # cos distance rescaled to (0,1)

  match_scores = test_pairs[test_pairs.match_pair==1]['cos_distance']
  mismatch_scores = test_pairs[test_pairs.match_pair==0]['cos_distance']

  # Plot model's stats
  genuine = match_scores.values
  imposter = mismatch_scores.values

  return genuine, imposter, test_pairs

def calculate_far_frr(thresholds, imposter_scores, genuine_scores):
    # Initialize lists to store FAR and FRR values
    far_values = []
    frr_values = []

    # Loop through each threshold and calculate FAR and FRR
    for threshold in thresholds:
        # False Acceptances: Imposter scores exceeding the threshold
        false_acceptances = np.sum(imposter_scores > threshold)
        # False Rejections: Genuine scores below the threshold
        false_rejections = np.sum(genuine_scores < threshold)

        # Total Imposter and Genuine attempts
        total_imposter_attempts = len(imposter_scores)
        total_genuine_attempts = len(genuine_scores)

        # Calculate FAR and FRR
        far = false_acceptances / total_imposter_attempts if total_imposter_attempts != 0 else 0
        frr = false_rejections / total_genuine_attempts if total_genuine_attempts != 0 else 0

        far_values.append(far)
        frr_values.append(frr)

    return far_values, frr_values

def find_EER(far_values, frr_values, thresholds):
    # Calculate the absolute differences between FAR and FRR
    delta = np.abs(np.array(far_values) - np.array(frr_values))

    # Find the index where the difference is minimum (EER point)
    eer_index = np.argmin(delta)

    # Return the FAR at EER, FRR at EER, and the threshold at EER
    return far_values[eer_index], frr_values[eer_index], thresholds[eer_index]

def plot_DET_curve(far_values, frr_values, addedPlots=None):
    plt.figure(figsize=(10, 6))
    plt.plot(far_values, frr_values, linestyle="--", color='blue', linewidth=4, label="DET Curve")
    if addedPlots is not None:
        addedPlots()
    plt.xlabel('False Acceptance Rate (FAR)')
    plt.ylabel('False Rejection Rate (FRR)')
    plt.title('Detection Error Tradeoff (DET) curve')
    plt.legend()
    plt.grid()
    plt.show()

def addedPlots():
    plt.plot(far_opt, frr_opt, 'ro', label="EER Point")
    plt.plot([1.0, 0.0], [0.0, 1.0], "k--")  # Draw the default DET Curve from 1-1

# %%
# Evalute model performance with Accuracy, FAR and FRR scores
pairs_df = evaluate_model(model)
# Out:
# Preparing stats from dev set
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 374ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 309ms/step

# %%
genuine_scores, imposter_scores, test_pairs = evaluate_model(model, pairs_file='./input/lfw-dataset/course-pairsDevTest.csv')

genuine_mean = genuine_scores.mean()
genuine_std_dev = genuine_scores.std()
imposter_mean = imposter_scores.mean()
imposter_std_dev = imposter_scores.std()
# Out:
# Preparing stats from dev set
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 347ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 8s 250ms/step

# %%
# Visualize the distribution of scores
plt.figure(figsize=(5, 3))
plt.hist(genuine_scores, bins=20, alpha=0.5, label='Genuine', color='green')
plt.hist(imposter_scores, bins=20, alpha=0.5, label='Imposter', color='red')
# plt.title("Distribution of Genuine and Imposter Scores")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.grid(), plt.legend(), plt.show()
# Out:
# (None, <matplotlib.legend.Legend at 0x78014bbf23b0>, None)

# %%
# Display the statistics

print(f"Genuine Scores:")
print(f"  Mean Score:           {genuine_mean:.4f}")
print(f"  Standard Deviation:   {genuine_std_dev:.4f}\n")

print(f"Imposter Scores:")
print(f"  Mean Score:           {imposter_mean:.4f}")
print(f"  Standard Deviation:   {imposter_std_dev:.4f}")
# Out:
# Genuine Scores:
#   Mean Score:           0.2702
#   Standard Deviation:   0.1112
#
# Imposter Scores:
#   Mean Score:           0.4535
#   Standard Deviation:   0.0887

# %%
thresholds = np.arange(0, 1.01, 0.01)

# %%
# Calculate FAR and FRR values for the given thresholds
far_values, frr_values = calculate_far_frr(thresholds, imposter_scores, genuine_scores)

# Find the EER (Equal Error Rate) point
far_opt, frr_opt, eer_threshold = find_EER(far_values, frr_values, thresholds)

# Calculate the EER value
eer = (far_opt + frr_opt) / 2
print(f"Equal Error Rate (EER): {eer:.4f}")
# Out:
# Equal Error Rate (EER): 0.8260

# %%
# Plot FAR and FRR against thresholds
plt.figure(figsize=(5, 3))
plt.plot(thresholds, far_values, label='FAR', color='red')
plt.plot(thresholds, frr_values, label='FRR', color='blue')
plt.axvline(eer_threshold, color='green', linestyle='--', label=f'EER = {eer:.4f} at \nThreshold = {eer_threshold:.2f}')
plt.xlabel('Threshold'), plt.ylabel('Error Rate')
# plt.title('FAR and FRR vs Threshold')
plt.legend(), plt.grid(), plt.show()
# Out:
# (<matplotlib.legend.Legend at 0x780092565c30>, None, None)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Combine genuine and imposter scores for ROC curve calculation
y_true = np.concatenate([np.ones_like(genuine_scores), np.zeros_like(imposter_scores)])
y_scores = np.concatenate([genuine_scores, imposter_scores])

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_scores)

# Calculate ROC AUC
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(5, 4))
plt.plot(fpr, tpr, color='blue', linestyle='--', linewidth=4, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.fill_between(fpr, tpr, alpha=0.2, color='blue') # Shade the area under the ROC curve

plt.plot([0, 1], [0, 1], color='k', linestyle='--') # Random Guess with AUC = 0.5
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver Operating Characteristic')
plt.legend(loc="best"), plt.grid()
plt.show()

print(f"ROC AUC: {roc_auc:.2f}")

plt.figure(figsize=(5, 4))
plt.plot(far_values, frr_values, linestyle="--", color='blue', linewidth=4, label="DET Curve")
if addedPlots is not None:
    addedPlots()
plt.xlabel('False Acceptance Rate (FAR)')
plt.ylabel('False Rejection Rate (FRR)')
# plt.title('Detection Error Tradeoff (DET) curve')
plt.legend()
plt.grid()
plt.show()
# Out:
# ROC AUC: 0.11

# %%
from sklearn.metrics import det_curve, DetCurveDisplay
import matplotlib.pyplot as plt

# Calculate the False Positive Rate (FAR), True Positive Rate (TPR), and thresholds
fpr, fnr, thresholds = det_curve(y_true, y_scores)

# Create a figure and axes
fig, ax = plt.subplots(figsize=(5, 5))

# Create the DetCurveDisplay object
display = DetCurveDisplay(fpr=fpr, fnr=fnr)

# Plot the DET curve on the created axes
display.plot(ax=ax)  # Pass the axes to the plot method

# Add title and grid
# ax.set_title("Detection Error Tradeoff (DET) Curve")
ax.grid(True)

plt.show()

# %% [markdown]
# ## MobileNetV2

# %%
# Set up learning rate and automatic LR decreasing
LR = 3e-4
lrate = ReduceLROnPlateau(monitor="val_loss", patience=3, factor=0.5, verbose=1)
optimizer = Adam(learning_rate=LR)
cce_loss = keras.losses.CategoricalCrossentropy(from_logits=False)

# Save best model weights
save_model = ModelCheckpoint(
    f'{weights_path}/custom-mobilenetv2.weights.h5',
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

from keras.applications import MobileNetV2
from keras.applications.mobilenet_v2 import preprocess_input

# Define the input layer
input_shape = target_size + (3,)
input_layer = Input(shape=input_shape)
input_layer = layers.Lambda(preprocess_input)(input_layer)

# Load the MobileNetV2 model without the top layers
base_model = MobileNetV2(
    include_top=False,
    weights="imagenet",  # Use pretrained weights on ImageNet
    input_tensor=input_layer,
    pooling="max",  # Global max pooling for feature aggregation
    classes=n_classes,
)

# Get the output of the base model
x = base_model.output

# Flatten the output of the base model
x = layers.Flatten()(x)

# Add dense layers for face embedding
x = Dense(embedding_size)(x)
x = ReLU()(x)
x = BatchNormalization(name='face_embedding')(x)
x = Dropout(dropout_rate)(x)

# Output layer for classification
output_layer = Dense(n_classes, activation='softmax')(x)

# Create the final model
modelM = Model(inputs=[input_layer], outputs=[output_layer], name='MobileNetV2')

# Compile the model
modelM.compile(optimizer=optimizer, loss=cce_loss, metrics=['accuracy'])
modelM.summary()

# Train the model
hist = modelM.fit(
    train_gen.repeat(10),  # Repeat dataset for additional epochs
    epochs=nb_epochs,
    validation_data=valid_gen,
    callbacks=[lrate, save_model]
)

# Save the trained model
modelM.save('/content/models/mobilenetv2.keras')
# Out:
# <ipython-input-63-98cf05ee0dba>:25: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(
# Model: "MobileNetV2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ keras_tensor_1164CLONE    │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 64, 64, 32)     │            864 │ keras_tensor_1164CLON… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 64, 64, 32)     │            128 │ Conv1[1][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 64, 64, 32)     │              0 │ bn_Conv1[1][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 64, 64, 32)     │            288 │ Conv1_relu[1][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 64, 64, 32)     │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 64, 64, 32)     │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 64, 64, 16)     │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 64, 64, 16)     │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 64, 64, 96)     │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 64, 64, 96)     │            384 │ block_1_expand[1][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 64, 64, 96)     │              0 │ block_1_expand_BN[1][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 65, 65, 96)     │              0 │ block_1_expand_relu[1… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 32, 32, 96)     │            864 │ block_1_pad[1][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 32, 32, 96)     │            384 │ block_1_depthwise[1][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 32, 32, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 32, 32, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 32, 32, 24)     │             96 │ block_1_project[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 32, 32, 144)    │          3,456 │ block_1_project_BN[1]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 32, 32, 144)    │            576 │ block_2_expand[1][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 32, 32, 144)    │              0 │ block_2_expand_BN[1][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 32, 32, 144)    │          1,296 │ block_2_expand_relu[1… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 32, 32, 144)    │            576 │ block_2_depthwise[1][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 32, 32, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 32, 32, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 32, 32, 24)     │             96 │ block_2_project[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 32, 32, 24)     │              0 │ block_1_project_BN[1]… │
# │                           │                        │                │ block_2_project_BN[1]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 32, 32, 144)    │          3,456 │ block_2_add[1][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 32, 32, 144)    │            576 │ block_3_expand[1][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 32, 32, 144)    │              0 │ block_3_expand_BN[1][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 33, 33, 144)    │              0 │ block_3_expand_relu[1… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 16, 16, 144)    │          1,296 │ block_3_pad[1][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 16, 16, 144)    │            576 │ block_3_depthwise[1][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 16, 16, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 16, 16, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 16, 16, 32)     │            128 │ block_3_project[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 16, 16, 192)    │          6,144 │ block_3_project_BN[1]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 16, 16, 192)    │            768 │ block_4_expand[1][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 16, 16, 192)    │              0 │ block_4_expand_BN[1][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 16, 16, 192)    │          1,728 │ block_4_expand_relu[1… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 16, 16, 192)    │            768 │ block_4_depthwise[1][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 16, 16, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 16, 16, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 16, 16, 32)     │            128 │ block_4_project[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 16, 16, 32)     │              0 │ block_3_project_BN[1]… │
# │                           │                        │                │ block_4_project_BN[1]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 16, 16, 192)    │          6,144 │ block_4_add[1][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 16, 16, 192)    │            768 │ block_5_expand[1][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 16, 16, 192)    │              0 │ block_5_expand_BN[1][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 16, 16, 192)    │          1,728 │ block_5_expand_relu[1… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 16, 16, 192)    │            768 │ block_5_depthwise[1][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 16, 16, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 16, 16, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 16, 16, 32)     │            128 │ block_5_project[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 16, 16, 32)     │              0 │ block_4_add[1][0],     │
# │                           │                        │                │ block_5_project_BN[1]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 16, 16, 192)    │          6,144 │ block_5_add[1][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 16, 16, 192)    │            768 │ block_6_expand[1][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 16, 16, 192)    │              0 │ block_6_expand_BN[1][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 17, 17, 192)    │              0 │ block_6_expand_relu[1… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 8, 8, 192)      │          1,728 │ block_6_pad[1][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 8, 8, 192)      │            768 │ block_6_depthwise[1][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 8, 8, 192)      │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 8, 8, 64)       │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 8, 8, 64)       │            256 │ block_6_project[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 8, 8, 384)      │         24,576 │ block_6_project_BN[1]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 8, 8, 384)      │          1,536 │ block_7_expand[1][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 8, 8, 384)      │              0 │ block_7_expand_BN[1][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 8, 8, 384)      │          3,456 │ block_7_expand_relu[1… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 8, 8, 384)      │          1,536 │ block_7_depthwise[1][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 8, 8, 384)      │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 8, 8, 64)       │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 8, 8, 64)       │            256 │ block_7_project[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 8, 8, 64)       │              0 │ block_6_project_BN[1]… │
# │                           │                        │                │ block_7_project_BN[1]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 8, 8, 384)      │         24,576 │ block_7_add[1][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 8, 8, 384)      │          1,536 │ block_8_expand[1][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 8, 8, 384)      │              0 │ block_8_expand_BN[1][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 8, 8, 384)      │          3,456 │ block_8_expand_relu[1… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 8, 8, 384)      │          1,536 │ block_8_depthwise[1][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 8, 8, 384)      │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 8, 8, 64)       │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 8, 8, 64)       │            256 │ block_8_project[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 8, 8, 64)       │              0 │ block_7_add[1][0],     │
# │                           │                        │                │ block_8_project_BN[1]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 8, 8, 384)      │         24,576 │ block_8_add[1][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 8, 8, 384)      │          1,536 │ block_9_expand[1][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 8, 8, 384)      │              0 │ block_9_expand_BN[1][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 8, 8, 384)      │          3,456 │ block_9_expand_relu[1… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 8, 8, 384)      │          1,536 │ block_9_depthwise[1][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 8, 8, 384)      │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 8, 8, 64)       │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 8, 8, 64)       │            256 │ block_9_project[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 8, 8, 64)       │              0 │ block_8_add[1][0],     │
# │                           │                        │                │ block_9_project_BN[1]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 8, 8, 384)      │         24,576 │ block_9_add[1][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 8, 8, 384)      │          1,536 │ block_10_expand[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 8, 8, 384)      │              0 │ block_10_expand_BN[1]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 8, 8, 384)      │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 8, 8, 384)      │          1,536 │ block_10_depthwise[1]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 8, 8, 384)      │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 8, 8, 96)       │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 8, 8, 96)       │            384 │ block_10_project[1][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 8, 8, 576)      │         55,296 │ block_10_project_BN[1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 8, 8, 576)      │          2,304 │ block_11_expand[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 8, 8, 576)      │              0 │ block_11_expand_BN[1]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 8, 8, 576)      │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 8, 8, 576)      │          2,304 │ block_11_depthwise[1]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 8, 8, 576)      │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 8, 8, 96)       │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 8, 8, 96)       │            384 │ block_11_project[1][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 8, 8, 96)       │              0 │ block_10_project_BN[1… │
# │                           │                        │                │ block_11_project_BN[1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 8, 8, 576)      │         55,296 │ block_11_add[1][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 8, 8, 576)      │          2,304 │ block_12_expand[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 8, 8, 576)      │              0 │ block_12_expand_BN[1]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 8, 8, 576)      │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 8, 8, 576)      │          2,304 │ block_12_depthwise[1]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 8, 8, 576)      │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 8, 8, 96)       │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 8, 8, 96)       │            384 │ block_12_project[1][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 8, 8, 96)       │              0 │ block_11_add[1][0],    │
# │                           │                        │                │ block_12_project_BN[1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 8, 8, 576)      │         55,296 │ block_12_add[1][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 8, 8, 576)      │          2,304 │ block_13_expand[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 8, 8, 576)      │              0 │ block_13_expand_BN[1]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 9, 9, 576)      │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 4, 4, 576)      │          5,184 │ block_13_pad[1][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 4, 4, 576)      │          2,304 │ block_13_depthwise[1]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 4, 4, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 4, 4, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 4, 4, 160)      │            640 │ block_13_project[1][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 4, 4, 960)      │        153,600 │ block_13_project_BN[1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 4, 4, 960)      │          3,840 │ block_14_expand[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 4, 4, 960)      │              0 │ block_14_expand_BN[1]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 4, 4, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 4, 4, 960)      │          3,840 │ block_14_depthwise[1]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 4, 4, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 4, 4, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 4, 4, 160)      │            640 │ block_14_project[1][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 4, 4, 160)      │              0 │ block_13_project_BN[1… │
# │                           │                        │                │ block_14_project_BN[1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 4, 4, 960)      │        153,600 │ block_14_add[1][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 4, 4, 960)      │          3,840 │ block_15_expand[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 4, 4, 960)      │              0 │ block_15_expand_BN[1]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 4, 4, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 4, 4, 960)      │          3,840 │ block_15_depthwise[1]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 4, 4, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 4, 4, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 4, 4, 160)      │            640 │ block_15_project[1][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 4, 4, 160)      │              0 │ block_14_add[1][0],    │
# │                           │                        │                │ block_15_project_BN[1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 4, 4, 960)      │        153,600 │ block_15_add[1][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 4, 4, 960)      │          3,840 │ block_16_expand[1][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 4, 4, 960)      │              0 │ block_16_expand_BN[1]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 4, 4, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 4, 4, 960)      │          3,840 │ block_16_depthwise[1]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 4, 4, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 4, 4, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 4, 4, 320)      │          1,280 │ block_16_project[1][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 4, 4, 1280)     │        409,600 │ block_16_project_BN[1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 4, 4, 1280)     │          5,120 │ Conv_1[1][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 4, 4, 1280)     │              0 │ Conv_1_bn[1][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_2    │ (None, 1280)           │              0 │ out_relu[1][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_4 (Flatten)       │ (None, 1280)           │              0 │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 128)            │        163,968 │ flatten_4[1][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 128)            │              0 │ dense_8[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ face_embedding            │ (None, 128)            │            512 │ re_lu_4[1][0]          │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 128)            │              0 │ face_embedding[1][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 46)             │          5,934 │ dropout_4[1][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,428,398 (9.26 MB)
#  Trainable params: 2,394,030 (9.13 MB)
#  Non-trainable params: 34,368 (134.25 KB)
# Epoch 1/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.6426 - loss: 1.6109
# Epoch 1: val_loss improved from inf to 3.50146, saving model to ./weights/custom-mobilenetv2.weights.h5
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 129s 142ms/step - accuracy: 0.6430 - loss: 1.6093 - val_accuracy: 0.2722 - val_loss: 3.5015 - learning_rate: 3.0000e-04
# Epoch 2/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 0.0153
# Epoch 2: val_loss improved from 3.50146 to 1.24266, saving model to ./weights/custom-mobilenetv2.weights.h5
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 104s 110ms/step - accuracy: 1.0000 - loss: 0.0153 - val_accuracy: 0.6857 - val_loss: 1.2427 - learning_rate: 3.0000e-04
# Epoch 3/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 3: val_loss improved from 1.24266 to 0.68017, saving model to ./weights/custom-mobilenetv2.weights.h5
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 82s 109ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.8376 - val_loss: 0.6802 - learning_rate: 3.0000e-04
# Epoch 4/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 4: val_loss improved from 0.68017 to 0.57367, saving model to ./weights/custom-mobilenetv2.weights.h5
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 65s 109ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8671 - val_loss: 0.5737 - learning_rate: 3.0000e-04
# Epoch 5/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 0.0015
# Epoch 5: val_loss improved from 0.57367 to 0.55017, saving model to ./weights/custom-mobilenetv2.weights.h5
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 83s 111ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8734 - val_loss: 0.5502 - learning_rate: 3.0000e-04
# Epoch 6/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 9.9754e-04
# Epoch 6: val_loss did not improve from 0.55017
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 80s 108ms/step - accuracy: 1.0000 - loss: 9.9742e-04 - val_accuracy: 0.8819 - val_loss: 0.5554 - learning_rate: 3.0000e-04
# Epoch 7/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 7.1583e-04
# Epoch 7: val_loss did not improve from 0.55017
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 65s 109ms/step - accuracy: 1.0000 - loss: 7.1572e-04 - val_accuracy: 0.8713 - val_loss: 0.5531 - learning_rate: 3.0000e-04
# Epoch 8/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 5.1826e-04
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 8: val_loss did not improve from 0.55017
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 65s 108ms/step - accuracy: 1.0000 - loss: 5.1820e-04 - val_accuracy: 0.8776 - val_loss: 0.5611 - learning_rate: 3.0000e-04
# Epoch 9/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 1.0000 - loss: 3.5229e-04
# Epoch 9: val_loss did not improve from 0.55017
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 83s 109ms/step - accuracy: 1.0000 - loss: 3.5227e-04 - val_accuracy: 0.8734 - val_loss: 0.5530 - learning_rate: 1.5000e-04
# Epoch 10/10
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 1.0000 - loss: 2.7628e-04
# Epoch 10: val_loss did not improve from 0.55017
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 66s 109ms/step - accuracy: 1.0000 - loss: 2.7626e-04 - val_accuracy: 0.8755 - val_loss: 0.5566 - learning_rate: 1.5000e-04

# %% [markdown]
# # Reload the model

# %%
from keras.models import load_model

model = load_model('/content/models/mobilenetv2.keras')

# %%
embedding_out = model.get_layer('face_embedding').output

template_extractor = Model(inputs=model.input, outputs=embedding_out)

# %%
plt.figure(figsize=(5, 4))
plt.plot(hist.history['loss'], label='Training Loss')
plt.plot(hist.history['val_loss'], label='Validation Loss')
#plt.title(f'Training and Validation Loss for {model.name}') # Add model name as title
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Evalute model performance with Accuracy, FAR and FRR scores
pairs_df = evaluate_model(model)
# Out:
# Preparing stats from dev set
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 344ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 220ms/step

# %%
def evaluate_model(model, pairs_file='./input/lfw-dataset/course-pairsDevTest.csv'):
  # Cut our model at the 'embedding' layer level and convert it to template extractor
  embedding_out = model.get_layer('face_embedding').output
  # Fix: Use model.input instead of [input_layer]
  template_extrator = Model(inputs=model.input, outputs=[embedding_out])

  # ... (rest of the function remains the same) ...
  # Read pairs matched and mismatched for dev dataset
  print('Preparing stats from dev set')
  test_pairs = pd.read_csv(pairs_file)
  test_pairs['img_fn1'] = test_pairs.apply(lambda row: name_to_image_path(img_root_dir, row['name1'], row['imagenum1']), axis=1)
  test_pairs['img_fn2'] = test_pairs.apply(lambda row: name_to_image_path(img_root_dir, row['name2'], row['imagenum2']), axis=1)

  # Apply the template model to all images
  test_pairs['template1'] = extract_template(test_pairs['img_fn1'], template_extrator, target_size)
  test_pairs['template2'] = extract_template(test_pairs['img_fn2'], template_extrator, target_size)
  test_pairs['cos_distance'] = test_pairs.apply(lambda row: distance.cosine(row['template1'], row['template2'])/2., axis=1)  # cos distance rescaled to (0,1)

  match_scores = test_pairs[test_pairs.match_pair==1]['cos_distance']
  mismatch_scores = test_pairs[test_pairs.match_pair==0]['cos_distance']

  # Plot model's stats
  genuine = match_scores.values
  imposter = mismatch_scores.values

  return genuine, imposter, test_pairs

def calculate_far_frr(thresholds, imposter_scores, genuine_scores):
    # Initialize lists to store FAR and FRR values
    far_values = []
    frr_values = []

    # Loop through each threshold and calculate FAR and FRR
    for threshold in thresholds:
        # False Acceptances: Imposter scores exceeding the threshold
        false_acceptances = np.sum(imposter_scores > threshold)
        # False Rejections: Genuine scores below the threshold
        false_rejections = np.sum(genuine_scores < threshold)

        # Total Imposter and Genuine attempts
        total_imposter_attempts = len(imposter_scores)
        total_genuine_attempts = len(genuine_scores)

        # Calculate FAR and FRR
        far = false_acceptances / total_imposter_attempts if total_imposter_attempts != 0 else 0
        frr = false_rejections / total_genuine_attempts if total_genuine_attempts != 0 else 0

        far_values.append(far)
        frr_values.append(frr)

    return far_values, frr_values

def find_EER(far_values, frr_values, thresholds):
    # Calculate the absolute differences between FAR and FRR
    delta = np.abs(np.array(far_values) - np.array(frr_values))

    # Find the index where the difference is minimum (EER point)
    eer_index = np.argmin(delta)

    # Return the FAR at EER, FRR at EER, and the threshold at EER
    return far_values[eer_index], frr_values[eer_index], thresholds[eer_index]

def plot_DET_curve(far_values, frr_values, addedPlots=None):
    plt.figure(figsize=(10, 6))
    plt.plot(far_values, frr_values, linestyle="--", color='blue', linewidth=4, label="DET Curve")
    if addedPlots is not None:
        addedPlots()
    plt.xlabel('False Acceptance Rate (FAR)')
    plt.ylabel('False Rejection Rate (FRR)')
    plt.title('Detection Error Tradeoff (DET) curve')
    plt.legend()
    plt.grid()
    plt.show()

def addedPlots():
    plt.plot(far_opt, frr_opt, 'ro', label="EER Point")
    plt.plot([1.0, 0.0], [0.0, 1.0], "k--")  # Draw the default DET Curve from 1-1

# %%
genuine_scores, imposter_scores, test_pairs = evaluate_model(model, pairs_file='./input/lfw-dataset/course-pairsDevTest.csv')

genuine_mean = genuine_scores.mean()
genuine_std_dev = genuine_scores.std()
imposter_mean = imposter_scores.mean()
imposter_std_dev = imposter_scores.std()
# Out:
# Preparing stats from dev set
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 12s 294ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 217ms/step

# %%
# Visualize the distribution of scores
plt.figure(figsize=(5, 3))
plt.hist(genuine_scores, bins=20, alpha=0.5, label='Genuine', color='green')
plt.hist(imposter_scores, bins=20, alpha=0.5, label='Imposter', color='red')
# plt.title("Distribution of Genuine and Imposter Scores")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.grid(), plt.legend(), plt.show()
# Out:
# (None, <matplotlib.legend.Legend at 0x7800920fb3d0>, None)

# %%
# Display the statistics

print(f"Genuine Scores:")
print(f"  Mean Score:           {genuine_mean:.4f}")
print(f"  Standard Deviation:   {genuine_std_dev:.4f}\n")

print(f"Imposter Scores:")
print(f"  Mean Score:           {imposter_mean:.4f}")
print(f"  Standard Deviation:   {imposter_std_dev:.4f}")
# Out:
# Genuine Scores:
#   Mean Score:           0.3536
#   Standard Deviation:   0.0994
#
# Imposter Scores:
#   Mean Score:           0.4842
#   Standard Deviation:   0.0763

# %%
# Define thresholds from 0 to 1 with a step size of 0.01
thresholds = np.arange(0, 1.01, 0.01)

# %%
# Calculate FAR and FRR values for the given thresholds
far_values, frr_values = calculate_far_frr(thresholds, imposter_scores, genuine_scores)

# Find the EER (Equal Error Rate) point
far_opt, frr_opt, eer_threshold = find_EER(far_values, frr_values, thresholds)

# Calculate the EER value
eer = (far_opt + frr_opt) / 2
print(f"Equal Error Rate (EER): {eer:.4f}")
# Out:
# Equal Error Rate (EER): 0.7860

# %%
# Plot FAR and FRR against thresholds
plt.figure(figsize=(5, 3))
plt.plot(thresholds, far_values, label='FAR', color='red')
plt.plot(thresholds, frr_values, label='FRR', color='blue')
plt.axvline(eer_threshold, color='green', linestyle='--', label=f'EER = {eer:.4f} at \nThreshold = {eer_threshold:.2f}')
plt.xlabel('Threshold'), plt.ylabel('Error Rate')
# plt.title('FAR and FRR vs Threshold')
plt.legend(), plt.grid(), plt.show()
# Out:
# (<matplotlib.legend.Legend at 0x78009263d300>, None, None)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Combine genuine and imposter scores for ROC curve calculation
y_true = np.concatenate([np.ones_like(genuine_scores), np.zeros_like(imposter_scores)])
y_scores = np.concatenate([genuine_scores, imposter_scores])

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_scores)

# Calculate ROC AUC
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(5, 4))
plt.plot(fpr, tpr, color='blue', linestyle='--', linewidth=4, label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.fill_between(fpr, tpr, alpha=0.2, color='blue') # Shade the area under the ROC curve

plt.plot([0, 1], [0, 1], color='k', linestyle='--') # Random Guess with AUC = 0.5
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# plt.title('Receiver Operating Characteristic')
plt.legend(loc="best"), plt.grid()
plt.show()

print(f"ROC AUC: {roc_auc:.2f}")

plt.figure(figsize=(5, 4))
plt.plot(far_values, frr_values, linestyle="--", color='blue', linewidth=4, label="DET Curve")
if addedPlots is not None:
    addedPlots()
plt.xlabel('False Acceptance Rate (FAR)')
plt.ylabel('False Rejection Rate (FRR)')
# plt.title('Detection Error Tradeoff (DET) curve')
plt.legend()
plt.grid()
plt.show()

from sklearn.metrics import roc_curve, RocCurveDisplay
import matplotlib.pyplot as plt

# Combine genuine and imposter scores for ROC curve calculation
y_true = np.concatenate([np.ones_like(genuine_scores), np.zeros_like(imposter_scores)])
y_scores = np.concatenate([genuine_scores, imposter_scores])

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_scores) # Ensure fpr, tpr, and thresholds are calculated together

# Create a figure and axes
fig, ax = plt.subplots(figsize=(5, 5))

# Create the RocCurveDisplay object using fpr and tpr
display = RocCurveDisplay(fpr=fpr, tpr=tpr)

# Plot the ROC curve on the created axes
display.plot(ax=ax)

# Add title and grid
ax.grid(True)
display.ax_.legend_.remove()

plt.show()

from sklearn.metrics import roc_curve, RocCurveDisplay
import matplotlib.pyplot as plt

# Combine genuine and imposter scores for ROC curve calculation
y_true = np.concatenate([np.ones_like(genuine_scores), np.zeros_like(imposter_scores)])
y_scores = np.concatenate([genuine_scores, imposter_scores])

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_true, y_scores) # Ensure fpr, tpr, and thresholds are calculated together

# Create a figure and axes
fig, ax = plt.subplots(figsize=(5, 5))

# Create the RocCurveDisplay object using fpr and tpr
display = RocCurveDisplay(fpr=fpr, tpr=tpr)

# Plot the ROC curve on the created axes
display.plot(ax=ax)

# Add title and grid
ax.grid(True)
display.ax_.legend_.remove()

plt.show()
# Out:
# ROC AUC: 0.15
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.metrics import det_curve, DetCurveDisplay
import matplotlib.pyplot as plt

# Calculate the False Positive Rate (FAR), True Positive Rate (TPR), and thresholds
fpr, fnr, thresholds = det_curve(y_true, y_scores)

# Create a figure and axes
fig, ax = plt.subplots(figsize=(5, 5))

# Create the DetCurveDisplay object
display = DetCurveDisplay(fpr=fpr, fnr=fnr)

# Plot the DET curve on the created axes
display.plot(ax=ax)  # Pass the axes to the plot method

# Add title and grid
# ax.set_title("Detection Error Tradeoff (DET) Curve")
ax.grid(True)

plt.show()

# %%
# Now let's calculate accuracy for test set
test_pairs['pred_match_pair'] = test_pairs['cos_distance'] < eer_threshold
test_pairs['pred_match_pair'] = test_pairs['pred_match_pair'].astype(int)

print(f'Accuracy: {accuracy_score(test_pairs.match_pair.values, test_pairs.pred_match_pair.values):.4f}')
# Out:
# Accuracy: 0.7860
